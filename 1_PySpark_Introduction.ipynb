# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-1103/PySparkTutorial/blob/main/1_PySpark_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark
import pandas as pd
from pyspark.sql import SparkSession

# %%
df = pd.read_csv('/content/gayle-175.csv')
df
# Out:
#           batsman  batsman_runs
# 0  AB de Villiers            31
# 1        CH Gayle           175
# 2       R Rampaul             0
# 3       SS Tiwary             2
# 4      TM Dilshan            33
# 5         V Kohli            11

# %%
spark = SparkSession.builder.appName("Practice").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://346aeeb31d55:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark_df = spark.read.csv('/content/gayle-175.csv')
spark_df.show()
# Out:
# +--------------+------------+
# |           _c0|         _c1|
# +--------------+------------+
# |       batsman|batsman_runs|
# |AB de Villiers|          31|
# |      CH Gayle|         175|
# |     R Rampaul|           0|
# |     SS Tiwary|           2|
# |    TM Dilshan|          33|
# |       V Kohli|          11|
# +--------------+------------+

# %%
spark_df = spark.read.option('header', 'true').csv('/content/gayle-175.csv')

# %%
type(spark_df)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
spark_df.show()
# Out:
# +--------------+------------+
# |       batsman|batsman_runs|
# +--------------+------------+
# |AB de Villiers|          31|
# |      CH Gayle|         175|
# |     R Rampaul|           0|
# |     SS Tiwary|           2|
# |    TM Dilshan|          33|
# |       V Kohli|          11|
# +--------------+------------+

# %%
spark_df.head(3)
# Out:
# [Row(batsman='AB de Villiers', batsman_runs='31'),
#  Row(batsman='CH Gayle', batsman_runs='175'),
#  Row(batsman='R Rampaul', batsman_runs='0')]

# %%
# info
spark_df.printSchema()
# Out:
# root
#  |-- batsman: string (nullable = true)
#  |-- batsman_runs: string (nullable = true)
